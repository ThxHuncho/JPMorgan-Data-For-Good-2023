# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.3 kB ? eta -:--:--
#      ----------- --------------------------- 30.7/102.3 kB 1.4 MB/s eta 0:00:01
#      ----------------------------------- --- 92.2/102.3 kB 1.3 MB/s eta 0:00:01
#      ----------------------------------- --- 92.2/102.3 kB 1.3 MB/s eta 0:00:01
#      ------------------------------------ 102.3/102.3 kB 657.4 kB/s eta 0:00:00
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\rodri\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\rodri\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\rodri\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rodri\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rodri\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rodri\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rodri\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rodri\anaconda3\lib\site-packages (from requests->folium) (2023.7.22)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e1/58/9289c6a03116025cdb61461d99b2493daa4967a80b13755463d71a0affeb/geopy-2.4.0-py3-none-any.whl.metadata
#   Downloading geopy-2.4.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 970.5 kB/s eta 0:00:00
# Downloading geopy-2.4.0-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------  122.9/125.4 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.0

# %%
import pandas as pd
df = pd.read_excel('Business Account.xlsx') 
df
# Out:
#      Business Account Customer Status              Type  \
# 0              C00001          Active          Customer
# 1              C00002          Active          Customer
# 2              C00003          Active          Customer
# 3              C00004          Active          Customer
# 4              C00005          Active          Customer
# ...               ...             ...               ...
# 3478           C19916        Prospect  Business Account
# 3479           C19917          Active          Customer
# 3480           C19918        Prospect  Business Account
# 3481           C19986        Prospect  Business Account
# 3482           C19987        Prospect  Business Account
#
#                Partner type    Class    Class Name  \
# 0                   Partner  02FONDA    Foundation
# 1                       NaN      NaN           NaN
# 2                       NaN      NaN           NaN
# 3                   Partner  01SIEGE  Headquarters
# 4                       NaN      NaN           NaN
# ...                     ...      ...           ...
# 3478                Partner  01SIEGE  Headquarters
# 3479               Prospect  01SIEGE  Headquarters
# 3480               Prospect  01SIEGE  Headquarters
# 3481  Institutional partner   21ETAT         State
# 3482                Partner  01SIEGE  Headquarters
#
#                                         Activity sector  \
# 0     HEALTH - SOCIAL - Social, Associations, Founda...
# 1                                                   NaN
# 2                                                   NaN
# 3     BUSINESS ADMINISTRATION - Consulting, Audit, A...
# 4                                                   NaN
# ...                                                 ...
# 3478  MEDIA - ARTS - SPORTS - Sports, Infrastructure...
# 3479  HEALTH - SOCIAL - Social, Associations, Founda...
# 3480  COMMUNICATION - Marketing, Advertising, Commun...
# 3481  SECTEUR PUBLIC - Etat & ses établissements pub...
# 3482  MEDIA - ARTS - SPORTS - Audiovisual, Media, Pu...
#
#      Parent Business Account  Owner Name  Follow-up with Postal Code  \
# 0                        NaN         2.0             NaN       69009
# 1                        NaN        13.0             NaN       69005
# 2                        NaN         NaN             NaN           0
# 3                        NaN        12.0             NaN       75008
# 4                        NaN         NaN             NaN           0
# ...                      ...         ...             ...         ...
# 3478                     NaN         7.0             NaN       75019
# 3479                     NaN        24.0             NaN       69800
# 3480                     NaN         NaN             NaN         NaN
# 3481                     NaN        17.0             NaN       93008
# 3482                     NaN         7.0             NaN       75002
#
#                             City State Country ID Country Name  \
# 0                           LYON   NaN         FR       France
# 1                           Lyon   NaN         FR       France
# 2                  Non renseigné   NaN         FR       France
# 3                          PARIS   NaN         FR       France
# 4                  Non renseigné   NaN         FR       France
# ...                          ...   ...        ...          ...
# 3478                       Paris   NaN         FR       France
# 3479               Saint  Priest   NaN         FR       France
# 3480  Montréal - Paris - Toronto   NaN         FR       France
# 3481                     Bobigny   NaN         FR       France
# 3482                       PARIS   NaN         FR       France
#
#                   Created On        Last Modified On
# 0    2021-02-02 15:35:10.183 2023-01-04 15:51:00.977
# 1    2021-02-02 15:35:11.213 2021-03-24 16:25:28.393
# 2    2021-02-02 15:35:11.457 2021-02-18 09:58:03.387
# 3    2021-02-02 15:35:11.770 2023-08-03 11:08:03.953
# 4    2021-02-02 15:35:12.013 2021-02-18 09:58:03.620
# ...                      ...                     ...
# 3478 2023-07-03 17:18:35.647 2023-07-03 17:18:35.647
# 3479 2023-07-04 09:04:13.730 2023-07-24 15:25:42.843
# 3480 2023-07-04 10:29:57.430 2023-07-04 10:29:57.430
# 3481 2023-07-05 15:37:58.080 2023-07-05 15:37:58.080
# 3482 2023-07-06 12:13:13.703 2023-07-06 12:13:13.703
#
# [3483 rows x 17 columns]

# %%
df = df.dropna(subset=['City'])
df = df[df['City'] != 'Non renseigné']
df = df[df['Partner type'] == 'Partner']
df['Last Modified On'] = pd.to_datetime(df['Last Modified On'])

# Select rows with "Last Modified On" after January 1, 2021
df= df[df['Last Modified On'] > '2021-01-01']
df
# Out:
#      Business Account Customer Status              Type Partner type  \
# 0              C00001          Active          Customer      Partner
# 3              C00004          Active          Customer      Partner
# 10             C00011          Active          Customer      Partner
# 11             C00012          Active          Customer      Partner
# 12             C00013          Active          Customer      Partner
# ...               ...             ...               ...          ...
# 3474           C19738        Prospect  Business Account      Partner
# 3476           C19744        Prospect  Business Account      Partner
# 3477           C19853        Prospect  Business Account      Partner
# 3478           C19916        Prospect  Business Account      Partner
# 3482           C19987        Prospect  Business Account      Partner
#
#          Class          Class Name  \
# 0      02FONDA          Foundation
# 3      01SIEGE        Headquarters
# 10     01SIEGE        Headquarters
# 11    04AGENCE              Agency
# 12    04AGENCE              Agency
# ...        ...                 ...
# 3474      11US  US - United States
# 3476   01SIEGE        Headquarters
# 3477   01SIEGE        Headquarters
# 3478   01SIEGE        Headquarters
# 3482   01SIEGE        Headquarters
#
#                                         Activity sector  \
# 0     HEALTH - SOCIAL - Social, Associations, Founda...
# 3     BUSINESS ADMINISTRATION - Consulting, Audit, A...
# 10                           HOTEL - CATERING - TOURISM
# 11                           HOTEL - CATERING - TOURISM
# 12    LAW - ECONOMICS - MANAGEMENT - Accounting, Man...
# ...                                                 ...
# 3474                         INDUSTRIES - Food industry
# 3476  PUBLIC SECTOR - Political & Administrative Ser...
# 3477  COMMUNICATION - Marketing, Advertising, Commun...
# 3478  MEDIA - ARTS - SPORTS - Sports, Infrastructure...
# 3482  MEDIA - ARTS - SPORTS - Audiovisual, Media, Pu...
#
#      Parent Business Account  Owner Name  Follow-up with Postal Code  \
# 0                        NaN         2.0             NaN       69009
# 3                        NaN        12.0             NaN       75008
# 10                       NaN        37.0             6.0       92445
# 11                       NaN        15.0             NaN       69002
# 12                       NaN        29.0             NaN       75008
# ...                      ...         ...             ...         ...
# 3474                     NaN        26.0             NaN    NY 10010
# 3476                     NaN         7.0             NaN       75017
# 3477                     NaN         7.0             NaN       92400
# 3478                     NaN         7.0             NaN       75019
# 3482                     NaN         7.0             NaN       75002
#
#                      City State Country ID Country Name  \
# 0                    LYON   NaN         FR       France
# 3                   PARIS   NaN         FR       France
# 10    ISSY-LES-MOULINEAUX   NaN         FR       France
# 11                   LYON   NaN         FR       France
# 12                  PARIS   NaN         FR       France
# ...                   ...   ...        ...          ...
# 3474             NEW-YORK   NaN         US   États-Unis
# 3476                Paris   NaN         FR       France
# 3477           Courbevoie   NaN         FR       France
# 3478                Paris   NaN         FR       France
# 3482                PARIS   NaN         FR       France
#
#                   Created On        Last Modified On
# 0    2021-02-02 15:35:10.183 2023-01-04 15:51:00.977
# 3    2021-02-02 15:35:11.770 2023-08-03 11:08:03.953
# 10   2021-02-02 15:35:15.180 2023-09-27 15:06:45.433
# 11   2021-02-02 15:35:16.200 2023-07-26 10:49:37.050
# 12   2021-02-02 15:35:16.487 2023-07-18 10:45:40.247
# ...                      ...                     ...
# 3474 2023-06-30 10:54:26.297 2023-06-30 10:54:26.297
# 3476 2023-07-03 12:18:51.170 2023-07-03 12:19:14.100
# 3477 2023-07-03 15:05:13.520 2023-07-03 15:05:13.520
# 3478 2023-07-03 17:18:35.647 2023-07-03 17:18:35.647
# 3482 2023-07-06 12:13:13.703 2023-07-06 12:13:13.703
#
# [886 rows x 17 columns]

# %%
# Function to clean and standardize city names
def clean_city_name(city):
    # Check if the value is a string
    if isinstance(city, str):
        # Remove leading/trailing whitespace and convert to title case
        cleaned_city = city.strip().title()
        # Additional cleaning can be added if needed
    else:
        # If the value is not a string, leave it as is
        cleaned_city = city

    return cleaned_city

# %%
df["City"] = df["City"].str.capitalize()
df
# Out:
#      Business Account Customer Status              Type Partner type  \
# 0              C00001          Active          Customer      Partner
# 3              C00004          Active          Customer      Partner
# 10             C00011          Active          Customer      Partner
# 11             C00012          Active          Customer      Partner
# 12             C00013          Active          Customer      Partner
# ...               ...             ...               ...          ...
# 3474           C19738        Prospect  Business Account      Partner
# 3476           C19744        Prospect  Business Account      Partner
# 3477           C19853        Prospect  Business Account      Partner
# 3478           C19916        Prospect  Business Account      Partner
# 3482           C19987        Prospect  Business Account      Partner
#
#          Class          Class Name  \
# 0      02FONDA          Foundation
# 3      01SIEGE        Headquarters
# 10     01SIEGE        Headquarters
# 11    04AGENCE              Agency
# 12    04AGENCE              Agency
# ...        ...                 ...
# 3474      11US  US - United States
# 3476   01SIEGE        Headquarters
# 3477   01SIEGE        Headquarters
# 3478   01SIEGE        Headquarters
# 3482   01SIEGE        Headquarters
#
#                                         Activity sector  \
# 0     HEALTH - SOCIAL - Social, Associations, Founda...
# 3     BUSINESS ADMINISTRATION - Consulting, Audit, A...
# 10                           HOTEL - CATERING - TOURISM
# 11                           HOTEL - CATERING - TOURISM
# 12    LAW - ECONOMICS - MANAGEMENT - Accounting, Man...
# ...                                                 ...
# 3474                         INDUSTRIES - Food industry
# 3476  PUBLIC SECTOR - Political & Administrative Ser...
# 3477  COMMUNICATION - Marketing, Advertising, Commun...
# 3478  MEDIA - ARTS - SPORTS - Sports, Infrastructure...
# 3482  MEDIA - ARTS - SPORTS - Audiovisual, Media, Pu...
#
#      Parent Business Account  Owner Name  Follow-up with Postal Code  \
# 0                        NaN         2.0             NaN       69009
# 3                        NaN        12.0             NaN       75008
# 10                       NaN        37.0             6.0       92445
# 11                       NaN        15.0             NaN       69002
# 12                       NaN        29.0             NaN       75008
# ...                      ...         ...             ...         ...
# 3474                     NaN        26.0             NaN    NY 10010
# 3476                     NaN         7.0             NaN       75017
# 3477                     NaN         7.0             NaN       92400
# 3478                     NaN         7.0             NaN       75019
# 3482                     NaN         7.0             NaN       75002
#
#                      City State Country ID Country Name  \
# 0                    Lyon   NaN         FR       France
# 3                   Paris   NaN         FR       France
# 10    Issy-les-moulineaux   NaN         FR       France
# 11                   Lyon   NaN         FR       France
# 12                  Paris   NaN         FR       France
# ...                   ...   ...        ...          ...
# 3474             New-york   NaN         US   États-Unis
# 3476                Paris   NaN         FR       France
# 3477           Courbevoie   NaN         FR       France
# 3478                Paris   NaN         FR       France
# 3482                Paris   NaN         FR       France
#
#                   Created On        Last Modified On
# 0    2021-02-02 15:35:10.183 2023-01-04 15:51:00.977
# 3    2021-02-02 15:35:11.770 2023-08-03 11:08:03.953
# 10   2021-02-02 15:35:15.180 2023-09-27 15:06:45.433
# 11   2021-02-02 15:35:16.200 2023-07-26 10:49:37.050
# 12   2021-02-02 15:35:16.487 2023-07-18 10:45:40.247
# ...                      ...                     ...
# 3474 2023-06-30 10:54:26.297 2023-06-30 10:54:26.297
# 3476 2023-07-03 12:18:51.170 2023-07-03 12:19:14.100
# 3477 2023-07-03 15:05:13.520 2023-07-03 15:05:13.520
# 3478 2023-07-03 17:18:35.647 2023-07-03 17:18:35.647
# 3482 2023-07-06 12:13:13.703 2023-07-06 12:13:13.703
#
# [886 rows x 17 columns]

# %%
numberdifferent_cities = df["City"].nunique()
numberdifferent_cities
# Out:
# 303

# %%
df["City"].value_counts()
# Out:
# Paris                          183
# Lyon                           150
# New york                        27
# Adresse non communiquee         20
# Marseille                       17
#                               ...
# Charbonnieres cedex              1
# Camphin-en-pevele                1
# Tassin la demi-lune              1
# Voisins-le-bretonneux cedex      1
# New-york                         1
# Name: City, Length: 303, dtype: int64

# %%
client_cities = df["City"].unique()
client_cities
# Out:
# array(['Lyon', 'Paris', 'Issy-les-moulineaux', 'Villeurbanne',
#        'Roissy en france', 'Saint-ouen cedex', 'Paris cedex 08',
#        'Rillieux la pape', 'Grenoble', 'Croix',
#        'Belleville-en-beaujolais', 'Nanterre', 'Lyon cedex 3',
#        'Le pont de claix', 'Boulogne billancourt', 'Suresnes', 'Genas',
#        'New york', 'Clichy cedex france', 'Marcy l etoile', 'Blendecques',
#        'Guyancourt', 'Paris cedex 13', 'Maisons-alfort cedex', 'Rungis',
#        'Puteaux', 'Breal-sous-montfort', 'Courbevoie cedex',
#        'Lyon cedex 07', 'Issy les moulineaux', "Villeuneuve d'ascq",
#        'Marcq en baroeul', 'Montrouge cedex', 'Lille', 'Rueil malmaison',
#        'Little ferry', 'Montreuil-sous-bois', 'Bron', "Villeneuve d'ascq",
#        'Crest', 'Créteil cedex', 'Limonest', 'Saint-denis', 'Marseille',
#        'Zurich', "L'horme", 'Ivry-sur-seine', 'Roubaix', 'Echirolles',
#        'Neuilly sur seine', 'Anneyron', 'Boulogne-billancourt',
#        'Carpentras', 'Asnieres sur seine cedex', 'Charvieu chavagneux',
#        'Elancourt', 'Pierre-benite', 'Venissieux', 'Neuilly',
#        'Chef-du-pont', 'Saint jean de moirans', 'Pierre benite',
#        'St genis les ollieres', "Champagne au mont d'or", 'Lyon cedex 02',
#        'Saint etienne', 'Saint priest cedex', 'Beynost cedex',
#        'Marcq en baroeul cedex', 'Lyon cedex 09', 'London', 'Neyron',
#        'Rieux cedex', 'Nanterre cedex', 'Gonesse', 'Rilleux-la-pape',
#        'Décines-charpieu', 'Colombes', 'Saint-vulbas', 'Chassieu',
#        'Saint ouen cedex', 'Sainte julie', 'Lambersart', 'Aubervilliers',
#        'Paris cedex 12', 'Vaulx-milieu', 'La madeleine cedex',
#        'Montrond les bains', 'Lyon cedex 03', 'Levallois perret',
#        'Le chambon feugerolles', 'Ecully', 'Chanas', 'Douai',
#        'Tassin la demi lune', 'Saint mande', 'Andrezieux', 'La ricamarie',
#        'Caluire-et-cuire', 'Lyon cedex 06', 'Champagne au mont d or',
#        'Lentilly', 'Wasquehal', 'Saint etienne cedex 1', 'Solaize',
#        'Onnaing', 'Nyon', 'Bordeaux', 'Vaulx-en-velin',
#        'Chatenay malabry', 'Marcq-en-baroeul', "L' isle d'abeau",
#        'Neuilly cedex', 'Leatherhead', 'Evry courcouronnes', 'Chicago',
#        'Sainte foy les lyon', 'Viviers du lac', 'Gentilly', 'Versailles',
#        'Leers', 'Balma', 'Boston', 'Anthis-mons', 'Bois colombes cedex',
#        'Chatillon', 'Noisy le grand', "Champagne au mont-d'or",
#        'Grenoble cedex 09', 'Aix en provence', 'Lille cedex',
#        "Villeneuve d'ascq cedex", 'Tourcoing', 'Montluel', 'Chessy',
#        'Peaugres', 'Winnetka', 'Clichy', 'Caluire et cuire',
#        'Marquette-lez-lille', 'Oullins', 'Villeurbanne cedex',
#        'Bensenville', 'Tarare', 'Sassenage', 'Montelimar',
#        'Charbonnieres cedex', 'Camphin-en-pevele', 'Tassin la demi-lune',
#        'Voisins-le-bretonneux cedex', 'Sainghin-en-melantois', 'Pantin',
#        'Boulogne', "Marcy l'etoile", 'Bridgewater', 'Chasse sur rhone',
#        'Lys les lannoy cedex', 'La madeleine', 'Wilmette', 'Harriman',
#        'Saint denis', 'Rillieux-la-pape', 'Saint-chamond',
#        "L'isle d'abeau", 'Roubaix cedex', 'Eguilles', 'Courbevoie',
#        'Frome', "St germain au mont d'or", 'Dardilly', 'Montélimar',
#        'Taluyers', 'Savigny', "Collonges au mont d'or", 'Francheville',
#        'Alancon', 'Chevilly larue', 'Corbeil-essonnes', 'Paris cedex 19',
#        'Ollioules', 'Beaune', 'Annecy', 'Aubiere', 'Bourg en bresse',
#        'St just st rambert', 'Villefranche-sur-saône', 'Montpellier',
#        'Londres', 'Caen - cedex 9', 'Veauche', 'Saint-etienne', 'Drancy',
#        'Malakoff', 'Arcueil cedex', 'Jouy-en-josas',
#        'Paris la défense cédex', 'Arnas', 'Vélizy-villacoublay',
#        'Montbonnot saint martin', 'Chambery cedex', 'Rosny sous bois',
#        'Saint genis laval', 'Saint chamond', 'Montverdun', 'Crolles',
#        'La tour en jarez', 'Blanquefort', 'Montreuil', 'Gardanne',
#        'Saint ouen sur seine', 'Bourg la reine', 'Lys lez lannoy',
#        'Les deux alpes', 'Thoissey', 'Blagnac', 'Saint priest',
#        'St priest', 'Saint ouen', 'Annecy cedex', 'Massy', 'Bezons',
#        'Chambery', 'Chamonix', 'Adresse non communiquee', 'La tronche',
#        'Adresse non communiuqee', '74370', 'Pont-eveque', 'Manosque',
#        'Bondoufle', 'Auriol', 'Cambridge', 'Riceboro', 'Athis-mons',
#        'Paris la défense cedex', 'Lieusaint cedex', 'Roubaix cedex 1',
#        'Rueil-malmaison', 'Hamilton hm cx', 'Meylan',
#        'Asnières sur seine', 'Evry cedex', 'Saint uze', 'Anzin',
#        'Valence cedex 9', 'Trappes', 'Montrouge', 'Saint-priest',
#        'Henin-beaumont', 'Chably', 'Marly', 'Adresse non commmuniquee',
#        'Les mureaux', 'Epinam', 'Le vesinet', 'Genas cedex',
#        "Champagne-au-mont-d'or", 'La tour-de-salvagny', 'Limoges',
#        'Mons en baroeul', 'Laxou', 'Luxembourg', 'Bievres',
#        'Fontenay sous bois', 'Meyzieu', 'Mouvaux', 'Vulaines sur seine',
#        'Adresse non communiquée', 'Neuilly-sur-seine',
#        'Marseille cedex 02', 'Decines charpieu', 'Mérignac cedex france',
#        'London ec2n 4ay', 'Voiron', 'Colombe',
#        "Saint-didier-au-mont-d'or", 'Le cheylard', 'Bernin', 'Trevignin',
#        'Corenc', 'Vaujours', 'Bobigny', 'Bondoufle cedex',
#        'Villefranche sur saone', 'Cornella de llobrega', 'Niort', 'Lomme',
#        'Faches-thumesnil', 'Rueil malmaison cedex', 'Andrézieux-bouthéon',
#        "Saint didier au mont d'or", 'Flers en escrebieux', 'Saint paul',
#        'Meyzieu zi', 'Vitrolles', 'Sainghin en melantois', 'Suresne',
#        'Atlanta', 'Bruxelles', 'Monaco', 'Zug', 'Torino', 'New-york'],
#       dtype=object)

# %%
df["Customer Status"].unique()
# Out:
# array(['Active', 'Inactive', 'Prospect'], dtype=object)

# %% [markdown]
#  # Map of partners

# %%
#This code is really Long to run but works!

import folium
from geopy.geocoders import Nominatim

# Initialize the map centered on Europe
europe_map = folium.Map(location=[50, 10], zoom_start=4)

# Geocode the client cities to get their coordinates
geolocator = Nominatim(user_agent="client_locator")
client_locations = []

for city in client_cities:
    location = geolocator.geocode(city)
    if location:
        client_locations.append(location)

# Add markers for each client location
for location in client_locations:
    folium.Marker(
        location=[location.latitude, location.longitude],
        popup=location.address
    ).add_to(europe_map)

# Save the map to an HTML file
europe_map.save("client_locations_map.html")

# %% [markdown]
#  # Map of partners (Active, Inactive and Prospect)

# %%
#This code is really Long to run but works!

import folium
from geopy.geocoders import Nominatim
import pandas as pd


# Initialize the map centered on Europe
europe_map = folium.Map(location=[50, 10], zoom_start=4)

# Define colors for different Customer Status
colors = {
    "Active": "green",
    "Inactive": "red",
    "Prospect": "blue"
}

# Geocode the client cities to get their coordinates
geolocator = Nominatim(user_agent="client_locator")
client_locations = []

for _, row in df.iterrows():
    city = row["City"]
    status = row["Customer Status"]
    location = geolocator.geocode(city)
    if location:
        client_locations.append((location, status))

# Add markers for each client location with different colors based on Customer Status
for location, status in client_locations:
    folium.Marker(
        location=[location.latitude, location.longitude],
        popup=location.address,
        icon=folium.Icon(color=colors.get(status, "gray"))
    ).add_to(europe_map)

# Save the map to an HTML file
europe_map.save("client_locations_map.html")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 25
#      23 city = row["City"]
#      24 status = row["Customer Status"]
# ---> 25 location = geolocator.geocode(city)
#      26 if location:
#      27     client_locations.append((location, status))
#
# File ~\anaconda3\Lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~\anaconda3\Lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~\anaconda3\Lib\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#     474         return resp.json()
#
# File ~\anaconda3\Lib\site-packages\geopy\adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     480 def _request(self, url, *, timeout, headers):
#     481     try:
# --> 482         resp = self.session.get(url, timeout=timeout, headers=headers)
#     483     except Exception as error:
#     484         message = str(error)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('Best_city.csv')

df[100]
# Out:
#                      Unnamed: 0  New City
# 0                         PARIS       657
# 1                          LYON       470
# 2                 NON RENSEIGNÉ       374
# 3                     MARSEILLE        92
# 4                      NEW YORK        54
# ..                          ...       ...
# 727                      BEAUNE         1
# 728                      VIENNE         1
# 729              PARIS CEDEX 19         1
# 730          BRIVE LA GAILLARDE         1
# 731  MONTRÉAL - PARIS - TORONTO         1
#
# [732 rows x 2 columns]

# %%
import pandas as pd
# Sample DataFrame
data = pd.DataFrame({
    "ID": [1, 2, 1, 3, 2, 1, 2, 3, 3]
})

# Create a new column "Count" that contains the count of each unique ID
data['Count'] = data.groupby('ID')['ID'].transform('count')

print(data)
# Out:
#    ID  Count
# 0   1      3
# 1   2      3
# 2   1      3
# 3   3      3
# 4   2      3
# 5   1      3
# 6   2      3
# 7   3      3
# 8   3      3
